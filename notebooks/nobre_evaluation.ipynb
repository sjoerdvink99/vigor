# %% [markdown]
# # Simulation of User Preferences

# %%
import os
import altair as alt
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from vigor import generate_graphs, nobre_predicates as predicates, compute_metrics, Predicate, VIGOR, label_graphs, learn_predicates

# %% [markdown]
# ## Generate graphs
#
# 1. Generate graphs using the fast_gnp_random_graph function from networkx
# 2. Calculate statistics for each graph

# %%
file_path = '../data/generated_graphs_example.csv'
# all_graphs = generate_graphs(1000, 2, 200, file_path=file_path)
all_graphs = pd.read_csv(f'{file_path}')

# %%
graphs = all_graphs.sample(frac=.8, random_state=0)
test_graphs = all_graphs.loc[~all_graphs.index.isin(graphs.index)]

# %%
graphs.head()
# Out:
#       graph_type  is_directed_int  has_spatial_attributes  \
# 1144           4                0                       1
# 990            4                0                       1
# 478            2                0                       0
# 161            4                0                       0
# 1153           4                0                       0
#
#       has_temporal_attributes  is_bipartite  n_components  \
# 1144                        0             1             6
# 990                         0             0             2
# 478                         1             0             8
# 161                         1             0             4
# 1153                        0             0             1
#
#       avg_betweenness_centrality  avg_closeness_centrality  \
# 1144                    0.003506                  0.613409
# 990                     0.004779                  0.601250
# 478                     0.227273                  0.305556
# 161                     0.018649                  0.496490
# 1153                    0.004753                  0.560658
#
#       avg_eigenvector_centrality  avg_degree  ...  eccentricity_avg  n_nodes  \
# 1144                    0.073731   66.769231  ...          2.000000      182
# 990                     0.083575   47.007092  ...          2.000000      141
# 478                     0.288675    2.000000  ...          6.000000       12
# 161                     0.125289    9.192982  ...          3.035088       57
# 1153                    0.076448   35.856287  ...          2.035928      167
#
#       node_types  node_attributes  number_of_isolates   density  edge_types  \
# 1144           2               12                   0  0.368891           5
# 990            5               11                   0  0.335765           3
# 478            1               14                   0  0.181818           1
# 161            1               10                   0  0.164160           2
# 1153           3                5                   0  0.216002           1
#
#       edge_attributes  n_parallel_edges  n_self_loops
# 1144                4                 1             1
# 990                12                 5             5
# 478                 9                 3             4
# 161                14                 5             3
# 1153                2                 4             3
#
# [5 rows x 30 columns]

# %% [markdown]
# ## Sample designers
#
# We evaluate the ability of VIGOR to recover the rules that were used to represent simulated users. We design 3 versions of this simulated user: bob_informed, who follows the rules 100\% of the time; bob_semi_informed, who follows the rules 75\% of the time and chooses other visualizations randomly the other 25\% of the time; and bob_uninformed who follows the rules 50\% of the time and chooses other visualizations randomly the other 50\% of the time.

# %%
informed = label_graphs(graphs, predicates, conformance=1)
semi_informed = label_graphs(graphs, predicates, conformance=0.75)
uninformed = label_graphs(graphs, predicates, conformance=0.5)

# %%
informed
# Out:
# 1144    BIOFABRIC
# 990     BIOFABRIC
# 478        QUILTS
# 161     BIOFABRIC
# 1153       QUILTS
#           ...
# 414     BIOFABRIC
# 662     BIOFABRIC
# 1206    BIOFABRIC
# 1187    BIOFABRIC
# 1027       MATRIX
# Length: 974, dtype: object

# %% [markdown]
# ### Learning predicates from labeled data

# %%
graphs['graph_type'].value_counts()
# Out:
# graph_type
# 4    657
# 3    160
# 2     83
# 1     74
# Name: count, dtype: int64

# %%
graph_types = graphs['graph_type'].unique()
graphs['graph_type_' + pd.Series(graph_types).astype(str)] = (graphs['graph_type'].values[None] == graph_types[:,None]).astype(int).T
graphs = graphs.drop('graph_type', axis=1)

# %%
nan_counts = graphs.isna().sum()
graphs = graphs.drop('assortativity', axis=1)

# %%
learned_predicates_informed = learn_predicates(graphs, informed, 1000)
learned_predicates_semi_informed = learn_predicates(graphs, semi_informed, 1000)
learned_predicates_uninformed = learn_predicates(graphs, uninformed, 1000)
# Out:
# Learning predicates for BIOFABRIC
# [   0] loss 17.0614070892334
# [ 100] loss 15.621204376220703
# [ 200] loss 14.260096549987793
# [ 300] loss 12.80773639678955
# [ 400] loss 11.236026763916016
# [ 500] loss 9.845702171325684
# [ 600] loss 8.477493286132812
# [ 700] loss 7.0778703689575195
# [ 800] loss 5.5895609855651855
# [ 900] loss 3.8505022525787354
# [   0] loss 4.501351833343506
# [ 100] loss 4.122861862182617
# [ 200] loss 3.7623157501220703
# [ 300] loss 3.403964042663574
# [ 400] loss 3.040868043899536
# [ 500] loss 2.6698856353759766
# [ 600] loss 2.2911109924316406
# [ 700] loss 1.909831166267395
# [ 800] loss 1.5332194566726685
# [ 900] loss 1.161286473274231
# Learning predicates for QUILTS
# [   0] loss 4.221377372741699
# [ 100] loss 3.863262176513672
# [ 200] loss 3.524844169616699
# [ 300] loss 3.1887197494506836
# [ 400] loss 2.847761631011963
# [ 500] loss 2.499769926071167
# [ 600] loss 2.1457884311676025
# [ 700] loss 1.7909520864486694
# [ 800] loss 1.4409523010253906
# [ 900] loss 1.096062183380127
# [   0] loss 17.446645736694336
# [ 100] loss 15.973657608032227
# [ 200] loss 14.579044342041016
# [ 300] loss 13.079554557800293
# [ 400] loss 11.480696678161621
# [ 500] loss 10.067916870117188
# [ 600] loss 8.66926383972168
# [ 700] loss 7.237234115600586
# [ 800] loss 5.712306022644043
# [ 900] loss 3.9231011867523193
# Learning predicates for MATRIX
# [   0] loss 0.9173685312271118
# [ 100] loss 0.19793164730072021
# [ 200] loss 0.1813776046037674
# [ 300] loss 0.16467994451522827
# [ 400] loss 0.14889666438102722
# [ 500] loss 0.13217128813266754
# [ 600] loss 0.11648359149694443
# [ 700] loss 0.10353406518697739
# [ 800] loss 0.09402669966220856
# [ 900] loss 0.09056597203016281
# [   0] loss 23.623659133911133
# [ 100] loss 20.97233772277832
# [ 200] loss 18.90331268310547
# [ 300] loss 17.05281639099121
# [ 400] loss 15.211163520812988
# [ 500] loss 13.363058090209961
# [ 600] loss 11.489234924316406
# [ 700] loss 9.547595024108887
# [ 800] loss 7.424293041229248
# [ 900] loss 4.7325215339660645
# Learning predicates for NODELINK
# [   0] loss 3.306165933609009
# [ 100] loss 0.061728011816740036
# [ 200] loss 0.056597866117954254
# [ 300] loss 0.05165307596325874
# [ 400] loss 0.04768126830458641
# [ 500] loss 0.048487331718206406
# [ 600] loss 0.06551072746515274
# [ 700] loss 0.09316646307706833
# [ 800] loss 0.11821916699409485
# [ 900] loss 0.15030568838119507
# [   0] loss 36.6733512878418
# [ 100] loss 32.14712142944336
# [ 200] loss 29.194944381713867
# [ 300] loss 26.363052368164062
# [ 400] loss 23.542158126831055
# [ 500] loss 20.70084571838379
# [ 600] loss 17.788280487060547
# [ 700] loss 14.65816593170166
# [ 800] loss 11.245634078979492
# [ 900] loss 7.64169979095459
# Learning predicates for BIOFABRIC
# [   0] loss 13.336341857910156
# [ 100] loss 12.206587791442871
# [ 200] loss 11.142088890075684
# [ 300] loss 10.004734992980957
# [ 400] loss 8.777262687683105
# [ 500] loss 7.675627708435059
# [ 600] loss 6.612997055053711
# [ 700] loss 5.534892559051514
# [ 800] loss 4.407116413116455
# [ 900] loss 3.1495425701141357
# [   0] loss 8.162821769714355
# [ 100] loss 7.508090496063232
# [ 200] loss 6.8643412590026855
# [ 300] loss 6.221360683441162
# [ 400] loss 5.578638553619385
# [ 500] loss 4.932196140289307
# [ 600] loss 4.281453609466553
# [ 700] loss 3.622584342956543
# [ 800] loss 2.92749285697937
# [ 900] loss 2.1542885303497314
# Learning predicates for MATRIX
# [   0] loss 1.1545524597167969
# [ 100] loss 0.9366095662117004
# [ 200] loss 0.8261479139328003
# [ 300] loss 0.7170194983482361
# [ 400] loss 0.6138456463813782
# [ 500] loss 0.529500424861908
# [ 600] loss 0.46618160605430603
# [ 700] loss 0.4139014184474945
# [ 800] loss 0.36833226680755615
# [ 900] loss 0.3215755522251129
# [   0] loss 21.298763275146484
# [ 100] loss 19.232105255126953
# [ 200] loss 17.178062438964844
# [ 300] loss 15.477898597717285
# [ 400] loss 13.812583923339844
# [ 500] loss 12.144043922424316
# [ 600] loss 10.455374717712402
# [ 700] loss 8.712911605834961
# [ 800] loss 6.828491687774658
# [ 900] loss 4.513028144836426
# Learning predicates for QUILTS
# [   0] loss 3.9082226753234863
# [ 100] loss 3.574704885482788
# [ 200] loss 3.259943723678589
# [ 300] loss 2.9478023052215576
# [ 400] loss 2.6322402954101562
# [ 500] loss 2.310903310775757
# [ 600] loss 1.9838963747024536
# [ 700] loss 1.6543984413146973
# [ 800] loss 1.3274869918823242
# [ 900] loss 1.0060144662857056
# [   0] loss 17.783069610595703
# [ 100] loss 16.27730369567871
# [ 200] loss 14.849397659301758
# [ 300] loss 13.279145240783691
# [ 400] loss 11.683806419372559
# [ 500] loss 10.259705543518066
# [ 600] loss 8.837989807128906
# [ 700] loss 7.381280422210693
# [ 800] loss 5.829068183898926
# [ 900] loss 4.004811763763428
# Learning predicates for NODELINK_FACETING
# [   0] loss 0.8572534322738647
# [ 100] loss 0.6666799783706665
# [ 200] loss 0.6083468198776245
# [ 300] loss 0.5507532358169556
# [ 400] loss 0.4937017858028412
# [ 500] loss 0.43730634450912476
# [ 600] loss 0.38191676139831543
# [ 700] loss 0.32842889428138733
# [ 800] loss 0.2783198058605194
# [ 900] loss 0.23486652970314026
# [   0] loss 22.192359924316406
# [ 100] loss 20.062726974487305
# [ 200] loss 17.9309139251709
# [ 300] loss 16.16569709777832
# [ 400] loss 14.432886123657227
# [ 500] loss 12.69670581817627
# [ 600] loss 10.93957805633545
# [ 700] loss 9.126640319824219
# [ 800] loss 7.166758060455322
# [ 900] loss 4.7617669105529785
# Learning predicates for NODELINK
# [   0] loss 0.9635372161865234
# [ 100] loss 0.7891369462013245
# [ 200] loss 0.7218958139419556
# [ 300] loss 0.6549285054206848
# [ 400] loss 0.588101863861084
# [ 500] loss 0.5216158032417297
# [ 600] loss 0.45597711205482483
# [ 700] loss 0.39210250973701477
# [ 800] loss 0.33131057024002075
# [ 900] loss 0.2769297957420349
# [   0] loss 21.87061309814453
# [ 100] loss 19.810747146606445
# [ 200] loss 17.697532653808594
# [ 300] loss 15.941906929016113
# [ 400] loss 14.230961799621582
# [ 500] loss 12.516905784606934
# [ 600] loss 10.782266616821289
# [ 700] loss 8.992684364318848
# [ 800] loss 7.058439254760742
# [ 900] loss 4.685816287994385
# Learning predicates for TREEMAP
# [   0] loss 0.7023705840110779
# [ 100] loss 0.46751853823661804
# [ 200] loss 0.42200055718421936
# [ 300] loss 0.3779484033584595
# [ 400] loss 0.3354458212852478
# [ 500] loss 0.29481539130210876
# [ 600] loss 0.25624504685401917
# [ 700] loss 0.22028255462646484
# [ 800] loss 0.1881529837846756
# [ 900] loss 0.1617460548877716
# [   0] loss 22.792205810546875
# [ 100] loss 20.491313934326172
# [ 200] loss 18.347187042236328
# [ 300] loss 16.55621337890625
# [ 400] loss 14.784372329711914
# [ 500] loss 13.008407592773438
# [ 600] loss 11.210702896118164
# [ 700] loss 9.355481147766113
# [ 800] loss 7.348858833312988
# [ 900] loss 4.882988452911377
# Learning predicates for SUNBURST
# [   0] loss 0.9334097504615784
# [ 100] loss 0.7533432841300964
# [ 200] loss 0.6897656321525574
# [ 300] loss 0.626458466053009
# [ 400] loss 0.563316822052002
# [ 500] loss 0.5005552768707275
# [ 600] loss 0.43866899609565735
# [ 700] loss 0.3784376084804535
# [ 800] loss 0.32070645689964294
# [ 900] loss 0.2674761414527893
# [   0] loss 21.97991180419922
# [ 100] loss 19.89554214477539
# [ 200] loss 17.774890899658203
# [ 300] loss 16.01521110534668
# [ 400] loss 14.29594898223877
# [ 500] loss 12.573336601257324
# [ 600] loss 10.829693794250488
# [ 700] loss 9.02999496459961
# [ 800] loss 7.082324028015137
# [ 900] loss 4.682738780975342
# Learning predicates for NODELINK_POSITIONING
# [   0] loss 0.7621588706970215
# [ 100] loss 0.5187723636627197
# [ 200] loss 0.4747578203678131
# [ 300] loss 0.4311656057834625
# [ 400] loss 0.387801855802536
# [ 500] loss 0.3448607921600342
# [ 600] loss 0.30288103222846985
# [ 700] loss 0.2627812623977661
# [ 800] loss 0.2257990688085556
# [ 900] loss 0.19427764415740967
# [   0] loss 22.81592559814453
# [ 100] loss 20.556995391845703
# [ 200] loss 18.394275665283203
# [ 300] loss 16.59349250793457
# [ 400] loss 14.81459903717041
# [ 500] loss 13.031379699707031
# [ 600] loss 11.225863456726074
# [ 700] loss 9.3614501953125
# [ 800] loss 7.341613292694092
# [ 900] loss 4.847063064575195
# Learning predicates for MATRIX
# [   0] loss 1.604871392250061
# [ 100] loss 1.4786090850830078
# [ 200] loss 1.3529291152954102
# [ 300] loss 1.2281825542449951
# [ 400] loss 1.1073853969573975
# [ 500] loss 0.9904463887214661
# [ 600] loss 0.866894006729126
# [ 700] loss 0.7445697784423828
# [ 800] loss 0.6233001351356506
# [ 900] loss 0.5032957792282104
# [   0] loss 20.196929931640625
# [ 100] loss 18.374879837036133
# [ 200] loss 16.435726165771484
# [ 300] loss 14.73316478729248
# [ 400] loss 13.146125793457031
# [ 500] loss 11.559164047241211
# [ 600] loss 9.954629898071289
# [ 700] loss 8.30171012878418
# [ 800] loss 6.521488666534424
# [ 900] loss 4.36080265045166
# Learning predicates for BIOFABRIC
# [   0] loss 9.838171005249023
# [ 100] loss 9.03488540649414
# [ 200] loss 8.247447967529297
# [ 300] loss 7.473634719848633
# [ 400] loss 6.699631690979004
# [ 500] loss 5.922334671020508
# [ 600] loss 5.1336236000061035
# [ 700] loss 4.30897855758667
# [ 800] loss 3.409937858581543
# [ 900] loss 2.4419400691986084
# [   0] loss 11.649933815002441
# [ 100] loss 10.695412635803223
# [ 200] loss 9.76304817199707
# [ 300] loss 8.814484596252441
# [ 400] loss 7.79424524307251
# [ 500] loss 6.749706268310547
# [ 600] loss 5.793752670288086
# [ 700] loss 4.849200248718262
# [ 800] loss 3.8691070079803467
# [ 900] loss 2.79337477684021
# Learning predicates for QUILTS
# [   0] loss 3.433466911315918
# [ 100] loss 3.1460275650024414
# [ 200] loss 2.875514507293701
# [ 300] loss 2.6065542697906494
# [ 400] loss 2.33730149269104
# [ 500] loss 2.066263198852539
# [ 600] loss 1.7921218872070312
# [ 700] loss 1.5137848854064941
# [ 800] loss 1.2306269407272339
# [ 900] loss 0.9457699656486511
# [   0] loss 18.305898666381836
# [ 100] loss 16.73493766784668
# [ 200] loss 15.224813461303711
# [ 300] loss 13.51111888885498
# [ 400] loss 11.980411529541016
# [ 500] loss 10.528048515319824
# [ 600] loss 9.06557846069336
# [ 700] loss 7.564016342163086
# [ 800] loss 5.958438396453857
# [ 900] loss 4.0523529052734375
# Learning predicates for NODELINK
# [   0] loss 1.432843565940857
# [ 100] loss 1.2721456289291382
# [ 200] loss 1.1615474224090576
# [ 300] loss 1.0508151054382324
# [ 400] loss 0.9399858117103577
# [ 500] loss 0.829062283039093
# [ 600] loss 0.7179792523384094
# [ 700] loss 0.6067768335342407
# [ 800] loss 0.49619507789611816
# [ 900] loss 0.3904077410697937
# [   0] loss 20.858291625976562
# [ 100] loss 18.993125915527344
# [ 200] loss 17.069490432739258
# [ 300] loss 15.26751708984375
# [ 400] loss 13.624520301818848
# [ 500] loss 11.983755111694336
# [ 600] loss 10.324914932250977
# [ 700] loss 8.615965843200684
# [ 800] loss 6.775238037109375
# [ 900] loss 4.540799617767334
# Learning predicates for NODELINK_POSITIONING
# [   0] loss 1.5947048664093018
# [ 100] loss 1.4277565479278564
# [ 200] loss 1.3022457361221313
# [ 300] loss 1.1782152652740479
# [ 400] loss 1.0548259019851685
# [ 500] loss 0.9321373701095581
# [ 600] loss 0.8107625842094421
# [ 700] loss 0.6914014220237732
# [ 800] loss 0.5734097361564636
# [ 900] loss 0.4579618275165558
# [   0] loss 20.569557189941406
# [ 100] loss 18.72208023071289
# [ 200] loss 16.768840789794922
# [ 300] loss 15.027962684631348
# [ 400] loss 13.41187858581543
# [ 500] loss 11.79653549194336
# [ 600] loss 10.163528442382812
# [ 700] loss 8.481640815734863
# [ 800] loss 6.6713056564331055
# [ 900] loss 4.478102684020996
# Learning predicates for TREEMAP
# [   0] loss 1.4489431381225586
# [ 100] loss 1.289999008178711
# [ 200] loss 1.1805968284606934
# [ 300] loss 1.0719841718673706
# [ 400] loss 0.9639162421226501
# [ 500] loss 0.8566242456436157
# [ 600] loss 0.750482976436615
# [ 700] loss 0.6457618474960327
# [ 800] loss 0.5420622229576111
# [ 900] loss 0.4416108727455139
# [   0] loss 20.81405258178711
# [ 100] loss 18.911802291870117
# [ 200] loss 16.911502838134766
# [ 300] loss 15.183552742004395
# [ 400] loss 13.549213409423828
# [ 500] loss 11.91392993927002
# [ 600] loss 10.259989738464355
# [ 700] loss 8.555254936218262
# [ 800] loss 6.716855049133301
# [ 900] loss 4.4767231941223145
# Learning predicates for SUNBURST
# [   0] loss 1.3474457263946533
# [ 100] loss 1.1890513896942139
# [ 200] loss 1.0853849649429321
# [ 300] loss 0.9825356006622314
# [ 400] loss 0.8799664974212646
# [ 500] loss 0.7778177261352539
# [ 600] loss 0.6766658425331116
# [ 700] loss 0.5772808194160461
# [ 800] loss 0.48005983233451843
# [ 900] loss 0.38735994696617126
# [   0] loss 20.975976943969727
# [ 100] loss 19.06562042236328
# [ 200] loss 17.04584503173828
# [ 300] loss 15.303632736206055
# [ 400] loss 13.658520698547363
# [ 500] loss 12.01268196105957
# [ 600] loss 10.348185539245605
# [ 700] loss 8.632745742797852
# [ 800] loss 6.783325672149658
# [ 900] loss 4.531793117523193
# Learning predicates for NODELINK_FACETING
# [   0] loss 1.0949294567108154
# [ 100] loss 0.9329236745834351
# [ 200] loss 0.8510208129882812
# [ 300] loss 0.7700405120849609
# [ 400] loss 0.6900165677070618
# [ 500] loss 0.6111533641815186
# [ 600] loss 0.5344918370246887
# [ 700] loss 0.46129491925239563
# [ 800] loss 0.3913480341434479
# [ 900] loss 0.3250350058078766
# [   0] loss 21.48893165588379
# [ 100] loss 19.48573875427246
# [ 200] loss 17.404752731323242
# [ 300] loss 15.668481826782227
# [ 400] loss 13.986356735229492
# [ 500] loss 12.301763534545898
# [ 600] loss 10.597223281860352
# [ 700] loss 8.839022636413574
# [ 800] loss 6.9393720626831055
# [ 900] loss 4.610036849975586

# %% [markdown]
# ### Comparing learned predicates to initial predicates

# %% [markdown]
# #### Informed User

# %%
test_informed = label_graphs(test_graphs, predicates, conformance=1)
evaluation_informed = compute_metrics(predicates, learned_predicates_informed, graphs, test_graphs, informed, test_informed)
print(evaluation_informed)
# Out:
# {'BIOFABRIC': {'exact': {'n_nodes': {'iou': 0.0, 'deviation': 111.49999999991832, 'inclusion': 0}, 'graph_type_2': {'iou': 0.0, 'deviation': 0.75, 'inclusion': 0}, 'graph_type_1': {'iou': 0.0, 'deviation': 0.75, 'inclusion': 0}}, 'describe': {'precision': array([0.2063655, 0.       ]), 'recall': array([1., 0.]), 'f1': array([0.34212766, 0.        ]), 'accuracy': np.float64(0.20636550308008214)}, 'generalize': {'precision': array([0.19672131, 0.        ]), 'recall': array([1., 0.]), 'f1': array([0.32876712, 0.        ]), 'accuracy': np.float64(0.19672131147540983)}}, 'QUILTS': {'exact': {'n_nodes': {'iou': 0.0, 'deviation': 111.49999999991832, 'inclusion': 0}, 'graph_type_4': {'iou': 0.0, 'deviation': 0.25, 'inclusion': 1}, 'graph_type_3': {'iou': 0.0, 'deviation': 0.75, 'inclusion': 0}, 'graph_type_1': {'iou': 0.0, 'deviation': 0.75, 'inclusion': 0}}, 'describe': {'precision': array([0.80698152, 0.        ]), 'recall': array([1., 0.]), 'f1': array([0.89318182, 0.        ]), 'accuracy': np.float64(0.8069815195071869)}, 'generalize': {'precision': array([0.81967213, 0.        ]), 'recall': array([1., 0.]), 'f1': array([0.9009009, 0.       ]), 'accuracy': np.float64(0.819672131147541)}}, 'MATRIX': {'exact': {'n_nodes': {'iou': 0.0, 'deviation': 111.49999999991832, 'inclusion': 0}, 'graph_type_2': {'iou': 0.0, 'deviation': 0.75, 'inclusion': 0}, 'node_attributes': {'iou': 0.0, 'deviation': 3.9999999923333327, 'inclusion': 0}}, 'describe': {'precision': array([0.98973306, 0.        ]), 'recall': array([1., 0.]), 'f1': array([0.99484004, 0.        ]), 'accuracy': np.float64(0.9897330595482546)}, 'generalize': {'precision': array([0.98770492, 0.        ]), 'recall': array([1., 0.]), 'f1': array([0.99381443, 0.        ]), 'accuracy': np.float64(0.9877049180327869)}}, 'NODELINK': {'exact': {'n_nodes': {'iou': 0.0, 'deviation': 111.49999999991832, 'inclusion': 0}, 'graph_type_4': {'iou': 0.0, 'deviation': 0.25, 'inclusion': 1}, 'graph_type_3': {'iou': 0.0, 'deviation': 0.75, 'inclusion': 0}, 'graph_type_1': {'iou': 0.0, 'deviation': 0.75, 'inclusion': 0}}, 'describe': {'precision': array([0.99691992, 0.        ]), 'recall': array([1., 0.]), 'f1': array([0.99845758, 0.        ]), 'accuracy': np.float64(0.9969199178644764)}, 'generalize': {'precision': array([0.99590164, 0.        ]), 'recall': array([1., 0.]), 'f1': array([0.99794661, 0.        ]), 'accuracy': np.float64(0.9959016393442623)}}}

# %% [markdown]
# #### Semi-Informed User

# %%
test_semi_informed = label_graphs(test_graphs, predicates, conformance=0.75)
evaluation_semi_informed = compute_metrics(predicates, learned_predicates_semi_informed, graphs, test_graphs, semi_informed, test_semi_informed)
print(evaluation_semi_informed)
# Out:
# {'BIOFABRIC': {'exact': {'n_nodes': {'iou': 0.0, 'deviation': 111.49999999991832, 'inclusion': 0}, 'graph_type_2': {'iou': 0.0, 'deviation': 0.75, 'inclusion': 0}, 'graph_type_1': {'iou': 0.0, 'deviation': 0.75, 'inclusion': 0}}, 'describe': {'precision': array([0.38193018, 0.        ]), 'recall': array([1., 0.]), 'f1': array([0.55274889, 0.        ]), 'accuracy': np.float64(0.38193018480492813)}, 'generalize': {'precision': array([0.33606557, 0.        ]), 'recall': array([1., 0.]), 'f1': array([0.50306748, 0.        ]), 'accuracy': np.float64(0.3360655737704918)}}, 'MATRIX': {'exact': {'n_nodes': {'iou': 0.0, 'deviation': 111.49999999991832, 'inclusion': 0}, 'graph_type_2': {'iou': 0.0, 'deviation': 0.75, 'inclusion': 0}}, 'describe': {'precision': array([0.95995893, 0.        ]), 'recall': array([1., 0.]), 'f1': array([0.97957046, 0.        ]), 'accuracy': np.float64(0.9599589322381931)}, 'generalize': {'precision': array([0.95491803, 0.        ]), 'recall': array([1., 0.]), 'f1': array([0.9769392, 0.       ]), 'accuracy': np.float64(0.9549180327868853)}}, 'QUILTS': {'exact': {'n_nodes': {'iou': 0.0, 'deviation': 111.49999999991832, 'inclusion': 0}, 'graph_type_4': {'iou': 0.0, 'deviation': 0.25, 'inclusion': 1}, 'graph_type_3': {'iou': 0.0, 'deviation': 0.75, 'inclusion': 0}, 'graph_type_1': {'iou': 0.0, 'deviation': 0.75, 'inclusion': 0}}, 'describe': {'precision': array([0.82032854, 0.        ]), 'recall': array([1., 0.]), 'f1': array([0.90129724, 0.        ]), 'accuracy': np.float64(0.8203285420944558)}, 'generalize': {'precision': array([0.82786885, 0.        ]), 'recall': array([1., 0.]), 'f1': array([0.9058296, 0.       ]), 'accuracy': np.float64(0.8278688524590164)}}, 'NODELINK_FACETING': {'exact': {'n_nodes': {'iou': 0.0, 'deviation': 111.49999999991832, 'inclusion': 0}, 'graph_type_1': {'iou': 0.0, 'deviation': 0.75, 'inclusion': 0}}, 'describe': {'precision': array([0.9661191, 0.       ]), 'recall': array([1., 0.]), 'f1': array([0.98276762, 0.        ]), 'accuracy': np.float64(0.9661190965092402)}, 'generalize': {'precision': array([0.96311475, 0.        ]), 'recall': array([1., 0.]), 'f1': array([0.98121086, 0.        ]), 'accuracy': np.float64(0.9631147540983607)}}, 'NODELINK': {'exact': {'n_nodes': {'iou': 0.0, 'deviation': 111.49999999991832, 'inclusion': 0}, 'graph_type_4': {'iou': 0.0, 'deviation': 0.25, 'inclusion': 1}, 'graph_type_3': {'iou': 0.0, 'deviation': 0.75, 'inclusion': 0}, 'graph_type_1': {'iou': 0.0, 'deviation': 0.75, 'inclusion': 0}}, 'describe': {'precision': array([0.96098563, 0.        ]), 'recall': array([1., 0.]), 'f1': array([0.98010471, 0.        ]), 'accuracy': np.float64(0.9609856262833676)}, 'generalize': {'precision': array([0.98770492, 0.        ]), 'recall': array([1., 0.]), 'f1': array([0.99381443, 0.        ]), 'accuracy': np.float64(0.9877049180327869)}}, 'TREEMAP': {'exact': {'graph_type_4': {'iou': 0.0, 'deviation': 0.25, 'inclusion': 1}, 'graph_type_1': {'iou': 0.0, 'deviation': 0.75, 'inclusion': 0}}, 'describe': {'precision': array([0.97330595, 0.        ]), 'recall': array([1., 0.]), 'f1': array([0.98647242, 0.        ]), 'accuracy': np.float64(0.973305954825462)}, 'generalize': {'precision': array([0.9795082, 0.       ]), 'recall': array([1., 0.]), 'f1': array([0.98964803, 0.        ]), 'accuracy': np.float64(0.9795081967213115)}}, 'SUNBURST': {'exact': {'graph_type_4': {'iou': 0.0, 'deviation': 0.25, 'inclusion': 1}, 'graph_type_1': {'iou': 0.0, 'deviation': 0.75, 'inclusion': 0}}, 'describe': {'precision': array([0.96303901, 0.        ]), 'recall': array([1., 0.]), 'f1': array([0.98117155, 0.        ]), 'accuracy': np.float64(0.9630390143737166)}, 'generalize': {'precision': array([0.97131148, 0.        ]), 'recall': array([1., 0.]), 'f1': array([0.98544699, 0.        ]), 'accuracy': np.float64(0.9713114754098361)}}, 'NODELINK_POSITIONING': {'exact': {'n_nodes': {'iou': 0.0, 'deviation': 111.49999999991832, 'inclusion': 0}, 'graph_type_3': {'iou': 0.0, 'deviation': 0. ...

# %% [markdown]
# #### Unformed User

# %%
test_uninformed = label_graphs(test_graphs, predicates, conformance=0.5)
evaluation_uninformed = compute_metrics(predicates, learned_predicates_uninformed, graphs, test_graphs, uninformed, test_uninformed)
print(evaluation_uninformed)
# Out:
# {'MATRIX': {'exact': {'n_nodes': {'iou': 0.0, 'deviation': 111.49999999991832, 'inclusion': 0}, 'graph_type_2': {'iou': 0.0, 'deviation': 0.75, 'inclusion': 0}}, 'describe': {'precision': array([0.92402464, 0.        ]), 'recall': array([1., 0.]), 'f1': array([0.96051227, 0.        ]), 'accuracy': np.float64(0.9240246406570842)}, 'generalize': {'precision': array([0.93442623, 0.        ]), 'recall': array([1., 0.]), 'f1': array([0.96610169, 0.        ]), 'accuracy': np.float64(0.9344262295081968)}}, 'BIOFABRIC': {'exact': {'n_nodes': {'iou': 0.0, 'deviation': 111.49999999991832, 'inclusion': 0}, 'graph_type_2': {'iou': 0.0, 'deviation': 0.75, 'inclusion': 0}, 'graph_type_1': {'iou': 0.0, 'deviation': 0.75, 'inclusion': 0}}, 'describe': {'precision': array([0.54106776, 0.        ]), 'recall': array([1., 0.]), 'f1': array([0.70219853, 0.        ]), 'accuracy': np.float64(0.5410677618069816)}, 'generalize': {'precision': array([0.54918033, 0.        ]), 'recall': array([1., 0.]), 'f1': array([0.70899471, 0.        ]), 'accuracy': np.float64(0.5491803278688525)}}, 'QUILTS': {'exact': {'n_nodes': {'iou': 0.0, 'deviation': 111.49999999991832, 'inclusion': 0}, 'graph_type_4': {'iou': 0.0, 'deviation': 0.25, 'inclusion': 1}, 'graph_type_3': {'iou': 0.0, 'deviation': 0.75, 'inclusion': 0}, 'graph_type_1': {'iou': 0.0, 'deviation': 0.75, 'inclusion': 0}}, 'describe': {'precision': array([0.84291581, 0.        ]), 'recall': array([1., 0.]), 'f1': array([0.91476323, 0.        ]), 'accuracy': np.float64(0.8429158110882957)}, 'generalize': {'precision': array([0.85655738, 0.        ]), 'recall': array([1., 0.]), 'f1': array([0.92273731, 0.        ]), 'accuracy': np.float64(0.8565573770491803)}}, 'NODELINK': {'exact': {'n_nodes': {'iou': 0.0, 'deviation': 111.49999999991832, 'inclusion': 0}, 'graph_type_4': {'iou': 0.0, 'deviation': 0.25, 'inclusion': 1}, 'graph_type_3': {'iou': 0.0, 'deviation': 0.75, 'inclusion': 0}, 'graph_type_1': {'iou': 0.0, 'deviation': 0.75, 'inclusion': 0}}, 'describe': {'precision': array([0.93737166, 0.        ]), 'recall': array([1., 0.]), 'f1': array([0.96767356, 0.        ]), 'accuracy': np.float64(0.9373716632443532)}, 'generalize': {'precision': array([0.9057377, 0.       ]), 'recall': array([1., 0.]), 'f1': array([0.95053763, 0.        ]), 'accuracy': np.float64(0.9057377049180327)}}, 'NODELINK_POSITIONING': {'exact': {'n_nodes': {'iou': 0.0, 'deviation': 111.49999999991832, 'inclusion': 0}, 'graph_type_3': {'iou': 0.0, 'deviation': 0.75, 'inclusion': 0}, 'graph_type_1': {'iou': 0.0, 'deviation': 0.75, 'inclusion': 0}}, 'describe': {'precision': array([0.92710472, 0.        ]), 'recall': array([1., 0.]), 'f1': array([0.96217368, 0.        ]), 'accuracy': np.float64(0.9271047227926078)}, 'generalize': {'precision': array([0.92622951, 0.        ]), 'recall': array([1., 0.]), 'f1': array([0.96170213, 0.        ]), 'accuracy': np.float64(0.9262295081967213)}}, 'TREEMAP': {'exact': {'graph_type_4': {'iou': 0.0, 'deviation': 0.25, 'inclusion': 1}, 'graph_type_1': {'iou': 0.0, 'deviation': 0.75, 'inclusion': 0}}, 'describe': {'precision': array([0.93531828, 0.        ]), 'recall': array([1., 0.]), 'f1': array([0.96657825, 0.        ]), 'accuracy': np.float64(0.9353182751540041)}, 'generalize': {'precision': array([0.95901639, 0.        ]), 'recall': array([1., 0.]), 'f1': array([0.9790795, 0.       ]), 'accuracy': np.float64(0.9590163934426229)}}, 'SUNBURST': {'exact': {'graph_type_4': {'iou': 0.0, 'deviation': 0.25, 'inclusion': 1}, 'graph_type_1': {'iou': 0.0, 'deviation': 0.75, 'inclusion': 0}}, 'describe': {'precision': array([0.93942505, 0.        ]), 'recall': array([1., 0.]), 'f1': array([0.96876654, 0.        ]), 'accuracy': np.float64(0.9394250513347022)}, 'generalize': {'precision': array([0.91803279, 0.        ]), 'recall': array([1., 0.]), 'f1': array([0.95726496, 0.        ]), 'accuracy': np.float64(0.9180327868852459)}}, 'NODELINK_FACETING': {'exact': {'n_nodes': {'iou': 0.0, 'deviation': 111.49999999 ...

# %% [markdown]
# ### Visualizing Results

# %%
data = [evaluation_informed, evaluation_semi_informed, evaluation_uninformed]

# %% [markdown]
# #### Extract

# %%
evaluations = ['informed', 'semi-informed', 'uninformed']
visualizations = set(vis for d in data for vis in d.keys())

avg_deviation = {vis: {eval: 0 for eval in evaluations} for vis in visualizations}

for i, eval in enumerate(data):
    for vis in visualizations:
        deviations = []
        avg_deviation_round = []
        for entry in eval[vis]['exact'].values():
            avg_deviation_round.append(entry['deviation'])
        avg_deviation[vis][evaluations[i]] = np.mean(avg_deviation_round) if avg_deviation_round else 0
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 10
#       8 deviations = []
#       9 avg_deviation_round = []
# ---> 10 for entry in eval[vis]['exact'].values():
#      11     avg_deviation_round.append(entry['deviation'])
#      12 avg_deviation[vis][evaluations[i]] = np.mean(avg_deviation_round) if avg_deviation_round else 0
#
# KeyError: 'SUNBURST'

# %%
# Prepare data for plotting
x_labels = ["Informed", "Semi-Informed", "Uninformed"]
plot_data = []

for i, vis in enumerate(visualizations):
    for j, var in enumerate(evaluations):
        plot_data.append({
            'variable': var,
            'deviation': avg_deviation[vis][var],
            'visualization': vis
        })

# Convert to DataFrame
df = pd.DataFrame(plot_data)

# Create the Altair chart
chart = alt.Chart(df).mark_bar().encode(
    x=alt.X('variable:N', axis=alt.Axis(title='Variables')),
    y=alt.Y('deviation:Q', axis=alt.Axis(title='Average Deviation')),
    color='visualization:N',
    column='visualization:N',
    tooltip=['variable:N', 'deviation:Q', 'visualization:N']
).properties(
    title='Average Deviations per Variable for Each Visualization',
    width=150,
    height=300
)

# Configure chart appearance
chart.configure_view(
    stroke='transparent'
).configure_axis(
    labelFontSize=12,
    titleFontSize=14
).configure_title(
    fontSize=16,
    anchor='middle'
)

# Display the chart
chart.show()
# Out:
# alt.Chart(...)

# %% [markdown]
# #### Describe

# %%
describe = {eval: {"prec": 0, "recall": 0, 'acc': 0} for eval in evaluations}

# Iterate over each eval in data
for i, eval in enumerate(data):
    # Temporary lists for the current eval
    temp_accuracy = []
    temp_precision = []
    temp_recall = []

    # Iterate over each visualization (vis) in eval
    for vis in eval:
        print(i, vis, eval[vis]['describe'])
        # Get the values for accuracy, precision, and recall
        metr = eval[vis]['describe']
        acc = metr['accuracy']
        prec = metr['precision'][0]
        rec = metr['recall'][0]

        # Append the values to the temporary lists
        temp_accuracy.append(acc)
        temp_precision.append(prec)
        temp_recall.append(rec)

    # Store the averages in the res dictionary
    describe[evaluations[i]]['acc'] = np.mean(temp_accuracy)
    describe[evaluations[i]]['prec'] = np.mean(temp_precision)
    describe[evaluations[i]]['recall'] = np.mean(temp_recall)

print(describe)
# Out:
# [np.float64(0.8), np.float64(0.875), np.float64(0.8750000000000001), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]

# %%
# Extract values and create lists
accuracy = [describe['informed']['acc'], describe['semi-informed']['acc'], describe['uninformed']['acc']]
precision = [describe['informed']['prec'], describe['semi-informed']['prec'], describe['uninformed']['prec']]
recall = [describe['informed']['recall'], describe['semi-informed']['recall'], describe['uninformed']['recall']]

# Combine lists into a single list for the DataFrame
result = accuracy + precision + recall

describe = pd.DataFrame({
    'Metric': ['Accuracy', 'Accuracy', 'Accuracy', 
               'Precision', 'Precision', 'Precision',
               'Recall', 'Recall', 'Recall'],
    'Evaluation': ['Informed', 'Semi-Informed', 'Uninformed',
                   'Informed', 'Semi-Informed', 'Uninformed',
                   'Informed', 'Semi-Informed', 'Uninformed'],
    'Value': result
})

# Create the Altair chart
chart = alt.Chart(describe).mark_bar().encode(
    x=alt.X('Evaluation:N', title='Evaluation', axis=alt.Axis(labelAngle=0)),
    y=alt.Y('Value:Q', title='Value'),
    color='Evaluation:N',
    column='Metric:N',
    tooltip=['Evaluation:N', 'Value:Q']
).properties(
    title='Metric Evaluation Comparison',
    width=100
).configure_facet(
    spacing=10
)

# Show the chart
chart.show()
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Generalize

# %%
generalize = {eval: {"prec": 0, "recall": 0, 'acc': 0} for eval in evaluations}

# Iterate over each eval in data
for i, eval in enumerate(data):
    # Temporary lists for the current eval
    temp_accuracy = []
    temp_precision = []
    temp_recall = []

    # Iterate over each visualization (vis) in eval
    for vis in eval:
        print(i, eval[vis]['generalize'])
        # Get the values for accuracy, precision, and recall
        acc = eval[vis]['generalize']['accuracy']
        prec = eval[vis]['generalize']['precision']
        rec = eval[vis]['generalize']['recall']

        # Check if the values are arrays and take the first element if they are
        if isinstance(acc, (list, np.ndarray)):
            acc = acc[0]
        if isinstance(prec, (list, np.ndarray)):
            prec = prec[0]
        if isinstance(rec, (list, np.ndarray)):
            rec = rec[0]

        # Append the values to the temporary lists
        temp_accuracy.append(acc)
        temp_precision.append(prec)
        temp_recall.append(rec)

    # Store the averages in the res dictionary
    generalize[evaluations[i]]['acc'] = sum(temp_accuracy) / len(temp_accuracy) if temp_accuracy else 0
    generalize[evaluations[i]]['prec'] = sum(temp_precision) / len(temp_precision) if temp_precision else 0
    generalize[evaluations[i]]['recall'] = sum(temp_recall) / len(temp_recall) if temp_recall else 0

print(generalize)
# Out:
# [np.float64(0.8), np.float64(0.875), np.float64(0.8749999999999999), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]

# %%
generalize = pd.DataFrame({
    'Metric': ['Accuracy', 'Accuracy', 'Accuracy', 
               'Precision', 'Precision', 'Precision',
               'Recall', 'Recall', 'Recall'],
    'Evaluation': ['Informed', 'Semi-Informed', 'Uninformed',
                   'Informed', 'Semi-Informed', 'Uninformed',
                   'Informed', 'Semi-Informed', 'Uninformed'],
    'Value': result
})

# Create the Altair chart
chart = alt.Chart(generalize).mark_bar().encode(
    x=alt.X('Evaluation:N', title='Evaluation', axis=alt.Axis(labelAngle=0)),
    y=alt.Y('Value:Q', title='Value'),
    color='Evaluation:N',
    column='Metric:N',
).properties(
    title='Metric Evaluation Comparison',
    width=100
).configure_facet(
    spacing=10
)

# Show the chart
chart.show()
# Out:
# alt.Chart(...)
